# %% [markdown]
# # 모델 복잡도와 과적합

# %% [markdown]
# ## 1.단순한 모델 vs 복잡한 모델

# %% [markdown]
# ### (1) 환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
#라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 전처리
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# 모델링
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.svm import SVC, SVR
from sklearn.metrics import * 
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

# %% [markdown]
# * 데이터 불러오기

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Carseats.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %% [markdown]
# ### (2) 데이터 준비

# %%
# 데이터분할1
target = 'Sales'
x = data.drop(target, axis=1)
y = data.loc[:, target]

# 가변수화
dumm_cols = ['ShelveLoc','Education','Urban', 'US']
x = pd.get_dummies(x, columns = dumm_cols, drop_first = True)

# 데이터 분할2
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2
                                                  , random_state = 2022)

# 스케일링
scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train)
x_val_s = scaler.transform(x_val)

# %% [markdown]
# ### (3)가장 단순한 모델 : 평균 모델

# %%
x_train_s.shape[0]
# Out:
# 320

# %% [markdown]
# * 가장 단순한 모델(평균모델)
#     * knn : k를 최대로 크게하면 평균 모델이 됨.
#     * k의 최대값은 학습 데이터의 행 수

# %%
# 모델링
n = x_train_s.shape[0]
model = KNeighborsRegressor(n_neighbors = n) # train set의 행 수
model.fit(x_train_s, y_train)
pred_train = model.predict(x_train_s)

# %%
# 결과 plotting
def reg_plot(y, pred, title='') :
    plt.scatter(y, pred)
    lin_x = np.linspace(y.min(), y.max(), 20)
    plt.plot(lin_x, lin_x, color = 'gray')

    plt.title(title)
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.grid()
    plt.show()

# %%
print('y_train 의 평균 : ', y_train.mean())
reg_plot(y_train, pred_train)
# Out:
# y_train 의 평균 :  7.591281250000004

# %%
pred_train
# Out:
# array([7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125,
#        7.59128125, 7.59128125, 7.59128125, 7.59128125, 7.59128125])

# %% [markdown]
# ### (4)복잡도를 증가시켜가며 모델을 만들고 그림을 그려봅시다.
#
# * 300,100,30,10,5,4,3,2,1
# * k=가 1일때 가장 복잡한 모델!

# %%
# 아래 90의 숫자를 줄여가며 모델링을 수행해 봅시다.
for n in [300,100,30,10,5,4,3,2,1] :
    model = KNeighborsRegressor(n_neighbors = n) # train set의 행 수
    model.fit(x_train_s, y_train)
    pred = model.predict(x_train_s)

    # 결과 plotting
    reg_plot(y_train, pred, f'k = {n}')
    plt.show()

# %% [markdown]
# ### (5) 실습 : Decision Tree

# %% [markdown]
# * Decision Tree는 max_depth 값이 클 수록 복잡한 모델이 됩니다.
# * max_depth 값을 1부터 20까지 1씩 증가시켜가면서 역시 plot을 그려봅시다.

# %%
x_train
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  ShelveLoc_Good  \
# 206        162      67            0          27    160   77               0
# 13         115      28           11          29     86   53               1
# 118        112      88            2         243     99   62               0
# 242        124      46            0         199    135   52               0
  6.86165354,  6.86165354,  6.86165354,
#         6.86165354,  6.86165354,  6.86165354,  6.86165354,  6.86165354,
#         6.86165354, 10.39924242, 10.39924242,  6.86165354,  6.86165354,
#         6.86165354, 10.39924242,  6.86165354,  6.86165354,  6.86165354,
#        10.39924242,  6.86165354,  6.86165354, 10.39924242, 10.39924242,
#        10.39924242,  6.86165354,  6.86165354,  6.86165354,  6.86165354,
#        10.39924242,  6.86165354, 10.39924242, 10.39924242,  6.86165354,
#         6.86165354, 10.39924242,  6.86165354,  6.86165354,  6.86165354])

# %%
for n in range(1,21) :
    modelD = DecisionTreeRegressor(max_depth = n)
    modelD.fit(x_train,y_train)
    pred1 = modelD.predict(x_train)

    # 결과 plotting
    reg_plot(y_train, pred1, f'k = {n}')
    plt.show()

# %% [markdown]
# ## 2.복잡도와 과적합

# %% [markdown]
# ### (1) 데이터 준비

# %%
# mobile data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/mobile_cust_churn.csv"
data = pd.read_csv(path)
data = data.sample(5000, random_state = 2022)
data.drop(['id', 'REPORTED_USAGE_LEVEL','OVER_15MINS_CALLS_PER_MONTH'], axis = 1, inplace = True)
data.head()
# Out:
#        COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 3178         0  119512       51        31  248566            229
# 14926        1  142144      192        15  774317            581
# 15116        1  142308        0        79  306426            497
# 12733        1  113385        0         0  333599            819
# 14032        1   90348      209        10  637286            360
#
#        AVERAGE_CALL_DURATION REPORTED_SATISFACTION CONSIDERING_CHANGE_OF_PLAN  \
# 3178                       2              very_sat                considering
# 14926                      4                 unsat              never_thought
# 15116                      1                   sat                considering
# 12733                      6            very_unsat                considering
# 14032                      4                 unsat   actively_looking_into_it
#
#        CHURN
# 3178   LEAVE
# 14926  LEAVE
# 15116   STAY
# 12733  LEAVE
# 14032   STAY

# %% [markdown]
# |변수 명|내용|구분|
# |	----	|	----	|	----	|
# |	COLLEGE	|	대학졸업 여부(1,0) - 범주	|		|
# |	INCOME	|	연 수입액(달러)	|		|
# |	OVERAGE	|	월 초과사용 시간(분)	|		|
# |	LEFTOVER	|	월 사용 잔여시간비율(%)	|		|
# |	HOUSE	|	집 가격(달러)	|		|
# |	HANDSET_PRICE	|	핸드폰 가격(달러)	|		|
# |	AVERAGE_CALL_DURATION	|	평균 통화시간(분)	|		|
# |	REPORTED_SATISFACTION	|	만족도 설문('very_unsat', 'unsat', 'avg', 'sat', 'very_sat' ) - 범주	|		|
# |	CONSIDERING_CHANGE_OF_PLAN	|	변경 계획 설문('never_thought', 'no', 'perhaps', 'considering',   'actively_looking_into_it') - 범주	|		|
# |	**CHURN**	|	이탈여부(1 : 이탈, 0 : 잔류)	|	**Target**	|

# %%
# 데이터분할1
target = 'CHURN'
x = data.drop(target, axis=1)
y = data.loc[:, target]

# 가변수화
dumm_cols = ['REPORTED_SATISFACTION','CONSIDERING_CHANGE_OF_PLAN']
x = pd.get_dummies(x, columns = dumm_cols, drop_first = True)

# 데이터 분할2
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2
                                                  , random_state = 2022)

# 스케일링
scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train)
x_val_s = scaler.transform(x_val)

# %% [markdown]
# ### (2) Fitting Graph 그리기
#
# * 모델의 복잡도를 증가시켜가면서
# * train & validation set에 대해 예측 및 평가를 수행하고,
# * 결과를 그래프로 그리기

# %% [markdown]
# * Decision Tree
#     * Decision Tree는 나무의 크기가 클 수록 복잡한 모델
#     * 크기를 결정하는 파라미터는 max_depth

# %%
result_train = [] # train set을 가지고 예측한 결과
result_val = [] # val set을 가지고 예측한 결과
depth = list(range(1,21))

for d in depth :
    model = DecisionTreeClassifier(max_depth = d)
    model.fit(x_train, y_train)
    pred_tr, pred_val = model.predict(x_train), model.predict(x_val)
    result_train.append(accuracy_score(y_train, pred_tr))
    result_val.append(accuracy_score(y_val, pred_val))

# %%
pd.DataFrame({'max_depth': list(range(1,21)),'train_acc':result_train, 'val_acc':result_val})
# Out:
#     max_depth  train_acc  val_acc
# 0           1    0.61750    0.627
# 1           2    0.65400    0.679
# 2           3    0.69475    0.697
# 3           4    0.70775    0.690
# 4           5    0.72100    0.692
# 5           6    0.73700    0.680
# 6           7    0.75100    0.675
# 7           8    0.77050    0.666
# 8           9    0.79025    0.661
# 9          10    0.81700    0.653
# 10         11    0.84400    0.638
# 11         12    0.86900    0.629
# 12         13    0.90150    0.622
# 13         14    0.92300    0.609
# 14         15    0.94250    0.623
# 15         16    0.96025    0.599
# 16         17    0.97250    0.604
# 17         18    0.98350    0.601
# 18         19    0.98900    0.607
# 19         20    0.99450    0.597

# %% [markdown]
# 정분류율은 몇 %인가요?
# 값이 달라지나요? 값이 달라지는 원인은 무엇인가요?
# 값이 달라진다면 모델의 성능을 어떻게 믿을 수 있을까요?

# %%
plt.figure(figsize = (12,8))
plt.plot(depth, result_train, label = 'train_acc', marker = 'o')
plt.plot(depth, result_val, label = 'val_acc', marker = 'o')

plt.xlabel('Complexity')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# * 최적의 depth는?

# %%
3

# %% [markdown]
# ### (3) 실습 : KNN 알고리즘에 대해서 Fitting Graph를 그리시오.
# * 실습1의 코드를 이용하되, knn 알고리즘을 이용
# * k값을 1~100까지 증가시키면서 train / val 정확도를 측정하고
# * fitting graph를 그리시오

# %%
result_train2 = [] # train set을 가지고 예측한 결과
result_val2 = [] # val set을 가지고 예측한 결과
k_values = list(range(1,101))

for k in k_values :
    model = KNeighborsClassifier(n_neighbors = k)
    model.fit(x_train_s, y_train)
    pred_tr, pred_val = model.predict(x_train_s), model.predict(x_val_s)
    result_train2.append(accuracy_score(y_train, pred_tr))
    result_val2.append(accuracy_score(y_val, pred_val))

# %%
plt.figure(figsize=(12,8))
plt.plot(k_values,result_train2,label='train_acc',marker='o')
plt.plot(k_values,result_val2,label = 'val_acc',marker ='o')

plt.xlabel('Complexity')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# * 최적의 k 값은?

# %%
70
